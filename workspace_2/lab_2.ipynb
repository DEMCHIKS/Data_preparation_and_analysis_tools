# %% [markdown]
# <h2>Засоби підготовки та аналіз даних</h2>
#  <h2>Лабораторна робота №2</h2>
#
#  <h4>ФБ-24 Демченко Олександр</h4>
#
#
#   <h3>Хід виконання роботи</h3>

# %% [markdown]
# Постановка задачі
#
# <ol>
#     <li>Проаналізувати часові ряди глобальних продуктів по оцінці
#     вегетаційного здоров’я VHI (vegetation health index)
#     http://www.star.nesdis.noaa.gov/smcd/emb/vci/VH/index.php, який
#     надається Національною адміністрацією океанів та атмосфери США
#     NOAA (http://www.noaa.gov/);</li>
#     <li>Виявити особливості ходу індексу впродовж вегетаційного періоду
#     (вересень року-попередника – липень поточного року) в розрізі
#     областей України;</li>
#     <li>Додаткові завдання по фільтрації даних від викладача, який веде
#     практику.</li>
# </ol>

# %% [markdown]
# Створити env в якому будуть встановлені всі необхідні бібліотеки та
# налаштування для данної лабораторної роботи

# %% [markdown]
# Створимо директорію```(data_analysis)``` для виконання даної лабораторної роботи та піддиректорію```(workspace)``` в якій буде віртуальне середовище Python для необхідних бібліотек та налаштувань:<br>
# ```cd Desktop``` <br>
# ```mkdir data_analysis```<br>
# ```cd data_analysis```<br>
# ```mkdir workspace```<br>
# ```cd workspace```<br>
# ```pwd```<br>
#
# Якщо pip відсутній у вашій системі:
# ```sudo apt-get install python3-pip```
#
# Встановлення virtualenv:
# ```pip install virtualenv```
#
# Перевірка встановлення:
# ```virtualenv –version```
#
# Створення віртуального середовища вказавши відповідну назву(lab_2_venv):
# ```virtualenv lab_2_venv```
#
# Створення віртуального середовища(lab_2_venv) за допомогою інтерпретатора Python 3, розташованого за адресою ```/usr/bin/python3```<br>
# ```virtualenv -p /usr/bin/python3 lab_2_venv```<br>
# ```-p py, --python py``` - цільовий інтерпретатор, для якого потрібно створити віртуальний (або абсолютний шлях, або рядок ідентифікатора) (за замовчуванням: /usr/bin/python3)
#
# ```ll``` – переглянемо результат
#
# ```cd lab_2_venv``` – змінимо директорію на lab_2_venv.
#
# ```ls -l``` – переглянемо повний список.
#
# ```source lab_2_venv/bin/activate``` – активувати вірутальне середовище<br>
# ```deactivate``` – деактивувати вірутальне середовище

# %% [markdown]
# Для кожної із адміністративних одиниць України завантажити тестові
# структуровані файли, що містять значення VHI-індексу. Ця процедура
# має бути автоматизована, параметром процедури має бути індекс
# (номер) області. При зберіганні файлу до його імені потрібно додати
# дату та час завантаження;

# %% [markdown]
# Необхідні бібліотеки, які попередньо були встановлені у віртуальному середовищі:<br>
# ```pip install pandas tabulate```

# %%
import urllib.request
import pandas as pd
from datetime import datetime
import os
import time
import re
import tabulate
print("Setup complete!")
# Out:
# Setup complete!

# %%
def download_csv(country, year_1, year_2, type_data, directory):
    for province_ID in range(1, 28):
        url=f"https://www.star.nesdis.noaa.gov/smcd/emb/vci/VH/get_TS_admin.php?country={country}&provinceID={province_ID}&year1={year_1}&year2={year_2}&type={type_data}"
        
        retries = 3
        for attempt in range(retries):
            try:
                with urllib.request.urlopen(url) as wp:
                    text = wp.read()
                break
            except urllib.error.URLError as e:
                print(f"Error downloading data for ID {province_ID}: {e}")
                if attempt < retries - 1:
                    print(f"Retrying download for ID {province_ID} in 5 seconds...")
                    time.sleep(5)
                else:
                    print(f"Failed to download data for ID {province_ID} after {retries} attempts.")
                    continue

        current_time = datetime.now().strftime("%a, %Y-%m-%d %H:%M:%S")
        filename = f'NOAA_ID_{province_ID}_{current_time}.csv'
        filepath = os.path.join(directory, filename)

        try:
            with open(filepath, 'wb') as out:
                out.write(text)
            print(f"Proccess is downloading:\nfile_csv:{filename}...\n")
            print(f"File_csv:{filename} downloaded successfully.")
            print(f"="*80)
        except IOError as e:
            print(f"Error writing file {filename}: {e}")


def clean_directory(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"[+] Directory created successfully.")
    
    if input("Do you want to clean the directory? (y/n): ").lower() == 'y':
        for filename in os.listdir(directory):
            filepath = os.path.join(directory, filename)
            if os.path.exists(filepath):
                os.unlink(filepath)
        print(f"[+] Directory cleaned successfully.\n")                
    else:
        print(f"[+] Directory cleaning skipped.\n")

# %%
country="UKR"
year_1=1981
year_2=2024
type_data="Mean"
directory="/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"

clean_directory(directory)    
download_csv(country, year_1, year_2, type_data, directory)
# Out:
# [+] Directory cleaned successfully.
#
# Proccess is downloading:
# file_csv:NOAA_ID_1_Tue, 2024-03-26 11:47:20.csv...
#
# File_csv:NOAA_ID_1_Tue, 2024-03-26 11:47:20.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_2_Tue, 2024-03-26 11:47:21.csv...
#
# File_csv:NOAA_ID_2_Tue, 2024-03-26 11:47:21.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_3_Tue, 2024-03-26 11:47:22.csv...
#
# File_csv:NOAA_ID_3_Tue, 2024-03-26 11:47:22.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_4_Tue, 2024-03-26 11:47:23.csv...
#
# File_csv:NOAA_ID_4_Tue, 2024-03-26 11:47:23.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_5_Tue, 2024-03-26 11:47:24.csv...
#
# File_csv:NOAA_ID_5_Tue, 2024-03-26 11:47:24.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_6_Tue, 2024-03-26 11:47:24.csv...
#
# File_csv:NOAA_ID_6_Tue, 2024-03-26 11:47:24.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_7_Tue, 2024-03-26 11:47:25.csv...
#
# File_csv:NOAA_ID_7_Tue, 2024-03-26 11:47:25.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_8_Tue, 2024-03-26 11:47:26.csv...
#
# File_csv:NOAA_ID_8_Tue, 2024-03-26 11:47:26.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_9_Tue, 2024-03-26 11:47:27.csv...
#
# File_csv:NOAA_ID_9_Tue, 2024-03-26 11:47:27.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_10_Tue, 2024-03-26 11:47:28.csv...
#
# File_csv:NOAA_ID_10_Tue, 2024-03-26 11:47:28.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_11_Tue, 2024-03-26 11:47:29.csv...
#
# File_csv:NOAA_ID_11_Tue, 2024-03-26 11:47:29.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_12_Tue, 2024-03-26 11:47:30.csv...
#
# File_csv:NOAA_ID_12_Tue, 2024-03-26 11:47:30.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_13_Tue, 2024-03-26 11:47:31.csv...
#
# File_csv:NOAA_ID_13_Tue, 2024-03-26 11:47:31.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_14_Tue, 2024-03-26 11:47:32.csv...
#
# File_csv:NOAA_ID_14_Tue, 2024-03-26 11:47:32.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_15_Tue, 2024-03-26 11:47:33.csv...
#
# File_csv:NOAA_ID_15_Tue, 2024-03-26 11:47:33.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_16_Tue, 2024-03-26 11:47:33.csv...
#
# File_csv:NOAA_ID_16_Tue, 2024-03-26 11:47:33.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_17_Tue, 2024-03-26 11:47:34.csv...
#
# File_csv:NOAA_ID_17_Tue, 2024-03-26 11:47:34.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_18_Tue, 2024-03-26 11:47:35.csv...
#
# File_csv:NOAA_ID_18_Tue, 2024-03-26 11:47:35.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_19_Tue, 2024-03-26 11:47:36.csv...
#
# File_csv:NOAA_ID_19_Tue, 2024-03-26 11:47:36.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_20_Tue, 2024-03-26 11:47:37.csv...
#
# File_csv:NOAA_ID_20_Tue, 2024-03-26 11:47:37.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_21_Tue, 2024-03-26 11:47:38.csv...
#
# File_csv:NOAA_ID_21_Tue, 2024-03-26 11:47:38.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_22_Tue, 2024-03-26 11:47:39.csv...
#
# File_csv:NOAA_ID_22_Tue, 2024-03-26 11:47:39.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_23_Tue, 2024-03-26 11:47:40.csv...
#
# File_csv:NOAA_ID_23_Tue, 2024-03-26 11:47:40.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_24_Tue, 2024-03-26 11:47:41.csv...
#
# File_csv:NOAA_ID_24_Tue, 2024-03-26 11:47:41.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_25_Tue, 2024-03-26 11:47:42.csv...
#
# File_csv:NOAA_ID_25_Tue, 2024-03-26 11:47:42.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_26_Tue, 2024-03-26 11:47:43.csv...
#
# File_csv:NOAA_ID_26_Tue, 2024-03-26 11:47:43.csv downloaded successfully.
# ================================================================================
# Proccess is downloading:
# file_csv:NOAA_ID_27_Tue, 2024-03-26 11:47:43.csv...
#
# File_csv:NOAA_ID_27_Tue, 2024-03-26 11:47:43.csv downloaded successfully.
# ================================================================================

# %% [markdown]
# Зчитати завантажені текстові файли у фрейм (детальніше про роботу
# із фреймами буде розказано у подальших лабораторних роботах).
# Імена стовбців фрейму мають бути змістовними та легкими для
# сприйняття (не повинно бути спеціалізованих символів, пробілів
# тощо). Ця задача має бути реалізована у вигляді окремої процедури,
# яка на вхід приймає шлях до директорії, в якій зберігаються файли;

# %%
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

def read_csv_file(filepath):
    headers = ['Year', 'Week', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI', 'empty']
    try:
        df = pd.read_csv(filepath, header=1, names=headers, converters={'Year': remove_html_tags})
        df = df.drop(df.loc[df['VHI'] == -1].index)
        df = df.drop("empty", axis=1)
        df = df.drop(df.index[-1])          
        return df
    
    except pd.errors.ParserError as e:
        print(f"Error reading {filepath}: {e}")
        return None

def read_data(directory):
    data_frames = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if filepath.endswith('.csv'):
            province_ID = filename.split('_')[2] if len(filename.split('_')) >= 3 else None                          
                      
            df = read_csv_file(filepath)  
            if int(province_ID) not in [12, 20]:          
                if df is not None:
                    df.insert(0, "PROVINCE_ID", int(province_ID), True)                   
                    df["Week"] = df["Week"].astype(int)
                    df["Year"] = df["Year"].astype(int)               
                    data_frames.append(df)                 
    
    data_frames.sort(key=lambda x: int(x["PROVINCE_ID"].iloc[0]))
    data_frames = pd.concat(data_frames).drop_duplicates().reset_index(drop=True)                      
    return data_frames


def print_dataframe(df):
    print(tabulate.tabulate(df, headers='keys', tablefmt="heavy_grid", showindex=False))

# %%
directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
data_frames_1 = read_data(directory)
print_dataframe(data_frames_1.head(10))
print_dataframe(data_frames_1.tail(10))
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   PROVINCE_ID ┃   Year ┃   Week ┃   SMN ┃    SMT ┃   VCI ┃   TCI ┃   VHI ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      1 ┃ 0.053 ┃ 260.31 ┃ 45.01 ┃ 39.46 ┃ 42.23 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      2 ┃ 0.054 ┃ 262.29 ┃ 46.83 ┃ 31.75 ┃ 39.29 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      3 ┃ 0.055 ┃ 263.82 ┃ 48.13 ┃ 27.24 ┃ 37.68 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      4 ┃ 0.053 ┃ 265.33 ┃ 46.09 ┃ 23.91 ┃ 35    ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      5 ┃ 0.05  ┃ 265.66 ┃ 41.46 ┃ 26.65 ┃ 34.06 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      6 ┃ 0.048 ┃ 266.55 ┃ 36.56 ┃ 29.46 ┃ 33.01 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      7 ┃ 0.048 ┃ 267.84 ┃ 32.17 ┃ 31.14 ┃ 31.65 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      8 ┃ 0.05  ┃ 269.3  ┃ 30.3  ┃ 32.5  ┃ 31.4  ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃      9 ┃ 0.052 ┃ 270.75 ┃ 28.23 ┃ 35.22 ┃ 31.73 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             1 ┃   1982 ┃     10 ┃ 0.056 ┃ 272.73 ┃ 25.25 ┃ 37.63 ┃ 31.44 ┃
# ┗━━━━━━━━━━━━━━━┻━━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━┻━━━━━━━┛
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   PROVINCE_ID ┃   Year ┃   Week ┃   SMN ┃    SMT ┃   VCI ┃   TCI ┃   VHI ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      3 ┃ 0.08  ┃ 260.91 ┃ 48.69 ┃ 46.11 ┃ 47.4  ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      4 ┃ 0.085 ┃ 261.81 ┃ 52.92 ┃ 44.17 ┃ 48.55 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      5 ┃ 0.092 ┃ 263.66 ┃ 54.07 ┃ 41.27 ┃ 47.67 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      6 ┃ 0.103 ┃ 266.42 ┃ 55.71 ┃ 36.65 ┃ 46.18 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      7 ┃ 0.119 ┃ 269.16 ┃ 60.71 ┃ 31.46 ┃ 46.08 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      8 ┃ 0.139 ┃ 271.77 ┃ 67.15 ┃ 27.58 ┃ 47.37 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃      9 ┃ 0.157 ┃ 274.29 ┃ 71.53 ┃ 24.54 ┃ 48.04 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃     10 ┃ 0.169 ┃ 276.28 ┃ 70.94 ┃ 24.84 ┃ 47.89 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃     11 ┃ 0.175 ┃ 277.04 ┃ 65.95 ┃ 29.5  ┃ 47.72 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            27 ┃   2024 ┃     12 ┃ 0.174 ┃ 277.61 ┃ 58.04 ┃ 38.91 ┃ 48.47 ┃
# ┗━━━━━━━━━━━━━━━┻━━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━┻━━━━━━━┛

# %%
def searching(directory):
    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)
        if file_path.endswith('.csv'):
            search_id_city(file_path)

def search_id_city(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        search_results = re.findall(r"= (\d+): ([\w'' '-]+),", content)     
        print(search_results) 
        return search_results

# %%
directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
searching(directory)
# Out:
# [('17', 'Odessa')]
# [('13', 'Kirovohrad')]
# [('20', "Sevastopol'")]
# [('2', 'Chernihiv')]
# [('21', 'Sumy')]
# [('26', 'Zaporizhzhya')]
# [('9', 'Kherson')]
# [('14', "Luhans'k")]
# [('6', "Donets'k")]
# [('16', 'Mykolayiv')]
# [('4', 'Crimea')]
# [('1', 'Cherkasy')]
# [('22', "Ternopil'")]
# [('18', 'Poltava')]
# [('25', 'Volyn')]
# [('11', 'Kiev')]
# [('19', 'Rivne')]
# [('3', 'Chernivtsi')]
# [('27', 'Zhytomyr')]
# [('23', 'Transcarpathia')]
# [('24', 'Vinnytsya')]
# [('7', "Ivano-Frankivs'k")]
# [('10', "Khmel'nyts'kyy")]
# [('15', "L'viv")]
# [('5', "Dnipropetrovs'k")]
# [('12', 'Kiev City')]
# [('8', 'Kharkiv')]

# %% [markdown]
# <h4>Реалізувати процедуру, яка змінить індекси областей, які використані на порталі NOAA на наступні:</h4>
#
# <pre>
#     №  Назва                               №   Назва
#     1. Вінницька                           13. Миколаївська
#     2. Волинська                           14. Одеська
#     3. Дніпропетровська                    15. Полтавська
#     4. Донецька                            16. Рівенська
#     5. Житомирська                         17. Сумська
#     6. Закарпатська                        18. Тернопільська
#     7. Запорізька                          19. Харківська
#     8. Івано-Франківська                   20. Херсонська
#     9. Київська                            21. Хмельницька
#     10.Кіровоградська                      22. Черкаська
#     11. Львівська                          23. Чернівецька
#     12. Луганська                          24. Чернігівська
#                                            25. Республіка Крим
# </pre>

# %%
def replace_function(data_frames):
    
    province_ID_dictionary = {
        16: 13,
        27: 5, 
        10: 21, 
        3: 23, 
        11: 9,
        25: 2,
        17: 14,
        21: 17,
        1: 22,    
        18: 15,
        6: 4,
        9: 20,   
        8: 19,
        19: 16,
        23: 6,
        7: 8,
        5: 3,
        26: 7,
        2: 24,
        4: 25,
        15: 11,
        22: 18,
        13: 10,
        24: 1,
        14: 12,
    }    
        
    data_frames_cp = data_frames.copy()
    data_frames_cp = data_frames_cp.replace({"PROVINCE_ID": province_ID_dictionary})   
      
    return data_frames_cp

# %%
directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
data_frames = read_data(directory)        
data_frames_replace = replace_function(data_frames_1) 
print_dataframe(data_frames_replace.head(10))
print_dataframe(data_frames_replace.tail(10))
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   PROVINCE_ID ┃   Year ┃   Week ┃   SMN ┃    SMT ┃   VCI ┃   TCI ┃   VHI ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      1 ┃ 0.053 ┃ 260.31 ┃ 45.01 ┃ 39.46 ┃ 42.23 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      2 ┃ 0.054 ┃ 262.29 ┃ 46.83 ┃ 31.75 ┃ 39.29 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      3 ┃ 0.055 ┃ 263.82 ┃ 48.13 ┃ 27.24 ┃ 37.68 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      4 ┃ 0.053 ┃ 265.33 ┃ 46.09 ┃ 23.91 ┃ 35    ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      5 ┃ 0.05  ┃ 265.66 ┃ 41.46 ┃ 26.65 ┃ 34.06 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      6 ┃ 0.048 ┃ 266.55 ┃ 36.56 ┃ 29.46 ┃ 33.01 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      7 ┃ 0.048 ┃ 267.84 ┃ 32.17 ┃ 31.14 ┃ 31.65 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      8 ┃ 0.05  ┃ 269.3  ┃ 30.3  ┃ 32.5  ┃ 31.4  ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃      9 ┃ 0.052 ┃ 270.75 ┃ 28.23 ┃ 35.22 ┃ 31.73 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃            22 ┃   1982 ┃     10 ┃ 0.056 ┃ 272.73 ┃ 25.25 ┃ 37.63 ┃ 31.44 ┃
# ┗━━━━━━━━━━━━━━━┻━━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━┻━━━━━━━┛
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   PROVINCE_ID ┃   Year ┃   Week ┃   SMN ┃    SMT ┃   VCI ┃   TCI ┃   VHI ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      3 ┃ 0.08  ┃ 260.91 ┃ 48.69 ┃ 46.11 ┃ 47.4  ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      4 ┃ 0.085 ┃ 261.81 ┃ 52.92 ┃ 44.17 ┃ 48.55 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      5 ┃ 0.092 ┃ 263.66 ┃ 54.07 ┃ 41.27 ┃ 47.67 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      6 ┃ 0.103 ┃ 266.42 ┃ 55.71 ┃ 36.65 ┃ 46.18 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      7 ┃ 0.119 ┃ 269.16 ┃ 60.71 ┃ 31.46 ┃ 46.08 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      8 ┃ 0.139 ┃ 271.77 ┃ 67.15 ┃ 27.58 ┃ 47.37 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃      9 ┃ 0.157 ┃ 274.29 ┃ 71.53 ┃ 24.54 ┃ 48.04 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃     10 ┃ 0.169 ┃ 276.28 ┃ 70.94 ┃ 24.84 ┃ 47.89 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃     11 ┃ 0.175 ┃ 277.04 ┃ 65.95 ┃ 29.5  ┃ 47.72 ┃
# ┣━━━━━━━━━━━━━━━╋━━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━━╋━━━━━━━╋━━━━━━━╋━━━━━━━┫
# ┃             5 ┃   2024 ┃     12 ┃ 0.174 ┃ 277.61 ┃ 58.04 ┃ 38.91 ┃ 48.47 ┃
# ┗━━━━━━━━━━━━━━━┻━━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━━┻━━━━━━━┻━━━━━━━┻━━━━━━━┛

# %% [markdown]
# Реалізувати процедури для формування вибірок наступного виду
# (включаючи елементи аналізу):
# <ol>
#     <li>Ряд VHI для області за вказаний рік, пошук екстремумів (min та max);</li>
#     <li>Ряд VHI за вказаний діапазон років для вказаних областей;
#         виявити роки, протягом яких екстремальні посухи торкнулися
#         більше вказаного відсотка областей по Україні (20% областей - 5 областей з 25);</li>
#     <li>Аналогічно для помірних посух</li>
# </ol>

# %%
def VHI_extremes(province_ID, year_1, year_2, df):
    
    PROVINCE_NAME_dict = {1: 'Вінницька',  2: 'Волинська',  3: 'Дніпропетровська',  4: 'Донецька',  5: 'Житомирська',
        6: 'Закарпатська',  7: 'Запорізька',  8: 'Івано-Франківська',  9: 'Київська',  10: 'Кіровоградська',
        11: 'Луганська',  12: 'Львівська',  13: 'Миколаївська',  14: 'Одеська',  15: 'Полтавська',
        16: 'Рівенська',  17: 'Сумська',  18: 'Тернопільська',  19: 'Харківська',  20: 'Херсонська',
        21: 'Хмельницька',  22: 'Черкаська',  23: 'Чернівецька',  24: 'Чернігівська',  25: 'Республіка Крим'}
    
    PROVINCE_NAME = PROVINCE_NAME_dict[province_ID]
    
    filtered_df = df[(df["PROVINCE_ID"] == province_ID) & (df["Year"] >= year_1) & (df["Year"] <= year_2)]
    vhi_values = filtered_df['VHI']
    
    # Filter out -1 values before calculating min and max
    vhi_values_filtered = vhi_values[vhi_values != -1]
    
    if not vhi_values_filtered.empty:
        min_value = vhi_values_filtered.min()
        max_value = vhi_values_filtered.max()    
    else:
        min_value = None
        max_value = None
    
    return [province_ID, PROVINCE_NAME, min_value, max_value]

def VHI_main():
    directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
    data_frames_1 = read_data(directory)          
    data_frames_replace = replace_function(data_frames_1) 
    
    year_1 = 2024
    year_2 = 2024
    
    vhi_extremes_data = []
    headers = ["Province ID", "PROVINCE_NAME", "Min VHI", "Max VHI"]
    
    for province_ID in range(1, 26):  
        vhi_extremes_data.append(VHI_extremes(province_ID, year_1, year_2, data_frames_replace)) 
    print(tabulate.tabulate(vhi_extremes_data, headers=headers, tablefmt="github"))

# %%
VHI_main()
# Out:
# |   Province ID | PROVINCE_NAME     |   Min VHI |   Max VHI |
# |---------------|-------------------|-----------|-----------|
# |             1 | Вінницька         |     42.15 |     51.08 |
# |             2 | Волинська         |     48.53 |     53.57 |
# |             3 | Дніпропетровська  |     39.74 |     49.55 |
# |             4 | Донецька          |     43.73 |     50.33 |
# |             5 | Житомирська       |     42.3  |     48.55 |
# |             6 | Закарпатська      |     37.54 |     50.75 |
# |             7 | Запорізька        |     35.39 |     44.58 |
# |             8 | Івано-Франківська |     42.85 |     49.8  |
# |             9 | Київська          |     42.35 |     48.15 |
# |            10 | Кіровоградська    |     38.64 |     47.26 |
# |            11 | Луганська         |     46.61 |     53.89 |
# |            12 | Львівська         |     40.93 |     50.41 |
# |            13 | Миколаївська      |     35.98 |     40.36 |
# |            14 | Одеська           |     36.34 |     39.38 |
# |            15 | Полтавська        |     39.18 |     54.26 |
# |            16 | Рівенська         |     42.65 |     50.33 |
# |            17 | Сумська           |     43.42 |     52.7  |
# |            18 | Тернопільська     |     41.93 |     48.65 |
# |            19 | Харківська        |     42.82 |     56.98 |
# |            20 | Херсонська        |     30.62 |     34.87 |
# |            21 | Хмельницька       |     42.08 |     48.59 |
# |            22 | Черкаська         |     41.91 |     49.32 |
# |            23 | Чернівецька       |     43.41 |     50.62 |
# |            24 | Чернігівська      |     42.07 |     48.55 |
# |            25 | Республіка Крим   |     38.18 |     41.96 |

# %%
def VHI_extremes(province_ID, year, df):
    
    PROVINCE_NAME_dict = {1: 'Вінницька',  2: 'Волинська',  3: 'Дніпропетровська',  4: 'Донецька',  5: 'Житомирська',
        6: 'Закарпатська',  7: 'Запорізька',  8: 'Івано-Франківська',  9: 'Київська',  10: 'Кіровоградська',
        11: 'Луганська',  12: 'Львівська',  13: 'Миколаївська',  14: 'Одеська',  15: 'Полтавська',
        16: 'Рівенська',  17: 'Сумська',  18: 'Тернопільська',  19: 'Харківська',  20: 'Херсонська',
        21: 'Хмельницька',  22: 'Черкаська',  23: 'Чернівецька',  24: 'Чернігівська',  25: 'Республіка Крим'}
    
    PROVINCE_NAME = PROVINCE_NAME_dict[province_ID]
    
    filtered_df = df[(df["PROVINCE_ID"] == province_ID) & (df["Year"] == year)]
    vhi_values = filtered_df['VHI']     
    vhi_values_filtered = vhi_values[vhi_values != -1]
    
    if not vhi_values_filtered.empty:
        min_value = vhi_values_filtered.min()
        max_value = vhi_values_filtered.max()    
    else:
        min_value = None
        max_value = None
    
    return [province_ID, PROVINCE_NAME, year, min_value, max_value, vhi_values.tolist()[:10]]  # Convert VHI series to list

def Task_main():
    directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
    data_frames_1 = read_data(directory)        
    data_frames_replace = replace_function(data_frames_1) 
    
    year=2020
    province_ID = 10
           
    vhi_extremes_data = []
    headers = ["Province ID", "PROVINCE_NAME", "Year", "Min VHI", "Max VHI", "VHI"]
    
    for province_ID in range(1, 26):  
        vhi_extremes_data.append(VHI_extremes(province_ID, year, data_frames_replace))        
    print(tabulate.tabulate(vhi_extremes_data, headers=headers, tablefmt="github"))

# %%
Task_main()
# Out:
# |   Province ID | PROVINCE_NAME     |   Year |   Min VHI |   Max VHI | VHI                                                                    |
# |---------------|-------------------|--------|-----------|-----------|------------------------------------------------------------------------|
# |             1 | Вінницька         |   2020 |     34.48 |     64.12 | [40.92, 43.19, 44.74, 45.29, 44.8, 43.92, 43.1, 42.88, 43.71, 45.61]   |
# |             2 | Волинська         |   2020 |     39.48 |     61.93 | [48.95, 49.23, 49.29, 49.4, 49.75, 50.26, 51.12, 51.59, 51.52, 51.72]  |
# |             3 | Дніпропетровська  |   2020 |     19.4  |     68.14 | [47.23, 46.99, 46.92, 46.55, 45.87, 45.14, 43.96, 43.39, 43.41, 43.13] |
# |             4 | Донецька          |   2020 |     17.88 |     59.14 | [44.72, 46.28, 47.98, 48.67, 48.03, 46.47, 43.85, 42.14, 40.76, 39.92] |
# |             5 | Житомирська       |   2020 |     35.05 |     58.33 | [42.82, 43.69, 44.52, 45.71, 45.62, 45.13, 45.76, 46.88, 47.05, 46.88] |
# |             6 | Закарпатська      |   2020 |     38.94 |     68.67 | [39.29, 39.08, 38.94, 39.47, 40.11, 41.64, 44.34, 47.42, 50.08, 52.64] |
# |             7 | Запорізька        |   2020 |     18.27 |     66.4  | [41.12, 41.58, 42.6, 42.46, 42.69, 42.25, 41.21, 41.04, 40.99, 40.42]  |
# |             8 | Івано-Франківська |   2020 |     39.78 |     62.91 | [44.11, 43.55, 43.18, 43.63, 43.27, 42.6, 42.66, 45.04, 47.26, 49.49]  |
# |             9 | Київська          |   2020 |     29.27 |     56.3  | [37.78, 38.41, 39.74, 41.9, 43.53, 43.37, 41.5, 39.53, 38.9, 39.07]    |
# |            10 | Кіровоградська    |   2020 |     22.73 |     63.63 | [39.74, 41.57, 42.45, 42.45, 41.3, 41.19, 41.17, 40.63, 40.22, 39.33]  |
# |            11 | Луганська         |   2020 |     41.35 |     63.06 | [45.02, 45.81, 46.16, 46.2, 46.67, 47.14, 48.05, 49.84, 51.32, 52.14]  |
# |            12 | Львівська         |   2020 |     21.29 |     64.39 | [48.84, 49.57, 48.91, 48.11, 45.53, 42.67, 40.47, 40.27, 40.19, 40.25] |
# |            13 | Миколаївська      |   2020 |     19.28 |     58.11 | [39.11, 39.9, 40.48, 40.82, 40.44, 40.61, 40.84, 41.65, 42.02, 41.88]  |
# |            14 | Одеська           |   2020 |     22.77 |     46.71 | [39.27, 40.51, 40.52, 41.39, 41.29, 41.17, 40.68, 41.47, 42.42, 42.58] |
# |            15 | Полтавська        |   2020 |     26.22 |     64.77 | [43.53, 44.0, 44.41, 44.99, 45.05, 43.83, 40.25, 37.56, 36.75, 36.15]  |
# |            16 | Рівенська         |   2020 |     37.68 |     66.01 | [44.97, 46.42, 46.36, 46.42, 46.78, 46.49, 47.49, 49.82, 50.68, 51.55] |
# |            17 | Сумська           |   2020 |     24.52 |     72.11 | [39.09, 40.71, 42.68, 46.15, 49.01, 49.21, 45.51, 40.86, 39.6, 40.16]  |
# |            18 | Тернопільська     |   2020 |     40.2  |     68.55 | [41.75, 43.9, 45.12, 45.32, 44.78, 43.67, 43.46, 44.86, 46.62, 48.32]  |
# |            19 | Харківська        |   2020 |     20.89 |     66.26 | [51.61, 52.53, 51.83, 52.64, 51.71, 48.7, 44.13, 41.16, 40.29, 40.16]  |
# |            20 | Херсонська        |   2020 |     24.49 |     63.49 | [45.94, 45.28, 44.67, 44.62, 44.56, 44.91, 44.9, 45.07, 45.25, 45.0]   |
# |            21 | Хмельницька       |   2020 |     37.43 |     67.65 | [40.56, 42.8, 44.59, 45.19, 44.02, 42.72, 42.89, 44.73, 46.63, 47.96]  |
# |            22 | Черкаська         |   2020 |     29.29 |     60.9  | [37.8, 39.94, 41.75, 42.76, 42.19, 41.29, 40.53, 39.7, 39.11, 38.47]   |
# |            23 | Чернівецька       |   2020 |     42.25 |     66.4  | [45.74, 45.54, 44.7, 44.35, 43.29, 42.42, 42.25, 43.95, 45.52, 47.07]  |
# |            24 | Чернігівська      |   2020 |     23.16 |     66.55 | [38.33, 37.57, 37.48, 40.47, 44.28, 46.02, 44.54, 42.12, 40.91, 40.95] |
# |            25 | Республіка Крим   |   2020 |     18.79 |     39.47 | [28.35, 29.64, 30.55, 30.76, 31.45, 32.67, 34.24, 35.82, 36.6, 37.05]  |

# %% [markdown]
# Ряд VHI за вказаний діапазон років для вказаних областей;
# виявити роки, протягом яких екстремальні посухи торкнулися
# більше вказаного відсотка областей по Україні (20% областей - 5 областей з 25);<br>
#
# Аналогічно для помірних посух

# %%
def VHI_extremes(province_ID, year_1, year_2, df):
    
    PROVINCE_NAME_dict = {1: 'Вінницька',  2: 'Волинська',  3: 'Дніпропетровська',  4: 'Донецька',  5: 'Житомирська',
        6: 'Закарпатська',  7: 'Запорізька',  8: 'Івано-Франківська',  9: 'Київська',  10: 'Кіровоградська',
        11: 'Луганська',  12: 'Львівська',  13: 'Миколаївська',  14: 'Одеська',  15: 'Полтавська',
        16: 'Рівенська',  17: 'Сумська',  18: 'Тернопільська',  19: 'Харківська',  20: 'Херсонська',
        21: 'Хмельницька',  22: 'Черкаська',  23: 'Чернівецька',  24: 'Чернігівська',  25: 'Республіка Крим'}
    
    PROVINCE_NAME = PROVINCE_NAME_dict[province_ID]
    
    filtered_df = df[(df["PROVINCE_ID"] == province_ID) & (df["Year"] >= year_1) & (df["Year"] <= year_2)]
    vhi_values = filtered_df['VHI']  
    
    return [province_ID, PROVINCE_NAME, year_1, year_2, vhi_values.tolist()[:10]]

def check_extreme_and_moderate(df, threshold_percentage, VHI):
    extreme_years = []
    years = sorted(df['Year'].unique())
    total_provinces = len(df['PROVINCE_ID'].unique())

    for year in years:
        condition = (df['Year'] == year) & (df['VHI'] <= VHI[1]) & (df['VHI'] >= VHI[0]) & (df['VHI'] != -1) 
        drought_count = df[condition].groupby('PROVINCE_ID').size().count()
        if (drought_count / total_provinces) * 100 > threshold_percentage:
            extreme_years.append(year)

    return extreme_years


def Task_main_2():    
    directory = "/home/kali/Desktop/data_analysis/workspace/lab_2_venv/data_csv"
    data_frames_1 = read_data(directory)
    data_frames_replace = replace_function(data_frames_1)

    year_1 = 1982
    year_2 = 2024  
        
    vhi_extremes_data = []
    headers = ["Province ID", "PROVINCE_NAME", "Year_Start", "Year_End", "VHI"]
    
    for province_ID in range(1, 11):  
        vhi_extremes_data.append(VHI_extremes(province_ID, year_1, year_2, data_frames_replace))    
    print(tabulate.tabulate(vhi_extremes_data, headers=headers, tablefmt="github"))

    VHI=[0, 15]
    extreme_years = check_extreme_and_moderate(data_frames_replace, 19, VHI)  # Extreme droughts
    print(f"="*155)
    print(f"Extreme drought years affecting more than 20% of provinces:", extreme_years)
    print(f"="*155)
        
    VHI=[15, 35]    
    moderate_years = check_extreme_and_moderate(data_frames_replace, 20, VHI)  # Moderate droughts
    print(f"Moderate drought years affecting more than 20% of provinces:", moderate_years)
    print(f"="*155)

# %%
Task_main_2()
# Out:
# |   Province ID | PROVINCE_NAME     |   Year_Start |   Year_End | VHI                                                                    |
# |---------------|-------------------|--------------|------------|------------------------------------------------------------------------|
# |             1 | Вінницька         |         1982 |       2024 | [45.9, 45.34, 44.88, 41.6, 39.29, 37.65, 35.03, 34.46, 35.04, 34.33]   |
# |             2 | Волинська         |         1982 |       2024 | [53.88, 50.97, 45.65, 40.04, 36.44, 35.14, 33.57, 33.23, 33.53, 35.07] |
# |             3 | Дніпропетровська  |         1982 |       2024 | [51.36, 47.14, 42.35, 38.53, 36.19, 34.71, 33.35, 33.65, 34.17, 34.27] |
# |             4 | Донецька          |         1982 |       2024 | [55.79, 51.93, 47.95, 43.2, 40.98, 40.76, 39.84, 37.98, 36.65, 35.87]  |
# |             5 | Житомирська       |         1982 |       2024 | [49.5, 48.62, 48.86, 46.28, 43.61, 41.71, 38.74, 37.61, 36.98, 36.44]  |
# |             6 | Закарпатська      |         1982 |       2024 | [54.44, 51.13, 45.73, 39.98, 34.6, 31.15, 30.7, 30.09, 29.24, 29.13]   |
# |             7 | Запорізька        |         1982 |       2024 | [45.61, 43.43, 41.91, 40.26, 38.94, 37.17, 34.99, 34.01, 32.8, 32.98]  |
# |             8 | Івано-Франківська |         1982 |       2024 | [53.0, 51.39, 49.42, 46.4, 42.96, 40.47, 39.22, 39.19, 38.83, 37.91]   |
# |             9 | Київська          |         1982 |       2024 | [47.76, 45.62, 44.03, 42.11, 40.3, 38.04, 35.11, 33.71, 32.97, 32.27]  |
# |            10 | Кіровоградська    |         1982 |       2024 | [39.23, 35.78, 33.64, 31.06, 30.08, 29.69, 29.55, 30.79, 32.42, 33.33] |
# ===========================================================================================================================================================
# Extreme drought years affecting more than 20% of provinces: [2007]
# ===========================================================================================================================================================
# Moderate drought years affecting more than 20% of provinces: [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# ===========================================================================================================================================================
